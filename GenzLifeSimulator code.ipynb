# %%
#PROGRAMMING FOR AI CLASS ASSIGNMENT:1

#Name  : Abdullah Majeed
#Class : BS(AI-3A)
#Enroll:01-136242-003

# %%
# Setup
user_profile = {}
stats = {"Points": 10, "Energy": 100, "Mood": "😄"}
titles_unlocked = []  # 🔒 Hidden goals system

# %%
# Chatbot responses
responses = {
    "hi": "Hey bestie! How's it going?",
    "how are you": "I'm vibing, wbu?",
    "bye": "Aww, see you soon!",
    "what's your name": "I'm Chatty, your virtual buddy!",
    "who created you": "I was created by OpenAI's amazing team!",
    "tell me a joke": "Why did the computer catch a cold? It left its Windows open!",
    "good morning": "Good morning! Hope your day starts with a smile :)",
    "good night": "Good night! Sleep tight and dream bright!",
    "thank you": "You're very welcome, bestie!",
    "what are you doing": "Just chatting with you, my favorite person!",
    "i am bored": "Let's fix that! Wanna hear a fun fact or a joke?",
    "do you like me": "Of course! You're awesome!",
    "what is your favorite color": "I'd say blue — calm and smart, like me!",
    "ok": "Okayyy :)",
    "sorry": "No worries! We're good!",
    "i love you": "Aww, love you too!"
}

# %%
# User_Info
name = input("Enter your name: ")
user_profile['Name'] = name
age = int(input("Enter your age: "))
user_profile['Age'] = age
print(f"Welcome, {name}! Let's chat ❤️")
# Out:
# Enter your name: Abdullah
# Enter your age: 19
# Welcome, Abdullah! Let's chat ❤️

# %%
# Hidden title unlock system
def check_hidden_goals():
    global titles_unlocked
    if stats["Points"] >= 50 and "🧠 Genius Mode" not in titles_unlocked:
        print("\n🎉 SECRET UNLOCKED: 🧠 Genius Mode! You're officially a brainiac!")
        titles_unlocked.append("🧠 Genius Mode")

    if stats["Energy"] >= 200 and "⚡ Energy Overlord" not in titles_unlocked:
        print("\n🎉 SECRET UNLOCKED: ⚡ Energy Overlord! You're unstoppable!")
        titles_unlocked.append("⚡ Energy Overlord")

    if stats["Points"] <= 0 and "😅 Struggle Champ" not in titles_unlocked:
        print("\n🎉 SECRET UNLOCKED: 😅 Struggle Champ! You've hit rock bottom but still smiling!")
        titles_unlocked.append("😅 Struggle Champ")
# Reset stats function
def reset_stats():
    stats["Points"] = 10
    stats["Energy"] = 100
    stats["Mood"] = "😄"
    print("\n🔄 Stats have been reset to default!")

# %%
# Main Chat Loop
while True:
    msg = input("You: ").lower()

    # exit condition
    if msg == "exit" or msg == "bye":
        print("Chatty: Aww, see you soon!")
        break

    elif msg == "stat" or msg == "mystats":
        for key in stats:
            print(key, ":", stats[key])
        if titles_unlocked:
            print("Titles unlocked:", ", ".join(titles_unlocked))
        else:
            print("No titles unlocked yet 👀")
    elif msg == "reset":
        reset_stats()
    elif msg in responses:
        print("Chatty:", responses[msg])

    elif msg == "play" or msg == "game":
        print("Chatty: Ooo want to play GenZ Life Simulator with me? (yes/no)")
        opt = input("You: ").lower()

        if opt == "yes" or opt == "y":
            print('STATS:')
            for key in stats:
                print(key, ":", stats[key])

            print("\n🎮 ACTIVITY MENU 🎮")
            print("1. Study  📚")
            print("2. Play   🎮")
            print("3. Eat    🍟")
            print("4. Sleep  😴")

            choice = input("\nChoose an activity (1-4): ")

            # STUDY
            if choice == "1":
                print("Chatty: Smart mode activated 🤓💡")
                stats["Points"] += 5
                stats["Energy"] -= 30
                stats["Mood"] = "😩"

            # PLAY
            elif choice == "2":
                print("Chatty: Grinding pixels, not problems 😎")
                stats["Points"] -= 5
                stats["Energy"] += 30
                stats["Mood"] = "🤩"

            # EAT
            elif choice == "3":
                print("Chatty: Bestie, never skip meals 🍔")
                stats["Points"] += 10
                stats["Energy"] += 100
                stats["Mood"] = "😋"

            # SLEEP
            elif choice == "4":
                print("Chatty: Zzz... You feel refreshed 😌")
                stats["Energy"] += 100
                stats["Mood"] = "😴"

            else:
                print("Chatty: Invalid choice bestie 😭")

            # Check for hidden achievements
            check_hidden_goals()

        else:
            print("Chatty: No worries! Maybe later 😄")

    else:
        print("Chatty: Hmm... I don't know what to say 😅")
# Out:
# You: play
# Chatty: Ooo want to play GenZ Life Simulator with me? (yes/no)
# You: yes
# STATS:
# Points : 10
# Energy : 100
# Mood : 😄
#
# 🎮 ACTIVITY MENU 🎮
# 1. Study  📚
# 2. Play   🎮
# 3. Eat    🍟
# 4. Sleep  😴
#
# Choose an activity (1-4): 2
# Chatty: Grinding pixels, not problems 😎
# You: play
# Chatty: Ooo want to play GenZ Life Simulator with me? (yes/no)
# You: yes
# STATS:
# Points : 5
# Energy : 130
# Mood : 🤩
#
# 🎮 ACTIVITY MENU 🎮
# 1. Study  📚
# 2. Play   🎮
# 3. Eat    🍟
# 4. Sleep  😴
#
# Choose an activity (1-4): 2
# Chatty: Grinding pixels, not problems 😎
#
# 🎉 SECRET UNLOCKED: 😅 Struggle Champ! You've hit rock bottom but still smiling!
# You: paly
# Chatty: Hmm... I don't know what to say 😅
# You: 4
# Chatty: Hmm... I don't know what to say 😅
# You: play
# Chatty: Ooo want to play GenZ Life Simulator with me? (yes/no)
# You: yes
# STATS:
# Points : 0
# Energy : 160
# Mood : 🤩
#
# 🎮 ACTIVITY MENU 🎮
# 1. Study  📚
# 2. Play   🎮
# 3. Eat    🍟
# 4. Sleep  😴
#
# ...
